# %%
import os
import sys
import pandas as pd
import numpy as np
import gzip
import subprocess

# %%
import time
import pysam
import seaborn as sns
import pyBigWig as pbw
import gffutils
import pybedtools
from skbio import io, Sequence
import editdistance

# %%
from CHEOPS.scripts import filPack as fil
from CHEOPS.scripts import PipelinePack_Cheops as pipa

# %%
prepare_databases = False
split_fastq = False
parse_bam = False
write_vcf = False
annotate = False
